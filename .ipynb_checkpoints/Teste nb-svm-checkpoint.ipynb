# %%
import pandas as pd, numpy as np
import sqlite3
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from unicodedata import normalize
from nltk.stem.snowball import SnowballStemmer
import re
from  nltk.corpus import stopwords

# %%
conn = sqlite3.connect("clientes4.db")
test = pd.read_sql("""select codigo as codigoCbo, printf('%s %s %s %s', nome ,descricao_sumaria, formacao_experiencia, condicoes_exercicio) as unificado
		from familia  
""", conn)

# %%
train = pd.read_csv("train.csv", sep = ";")
train
# Out:
#     codigoCbo  seguranca  relacionamento  saude  tecnologia  manufatura  \
# 0         101        1.0             NaN    NaN         NaN         NaN
# 1         102        1.0             NaN    NaN         NaN         NaN
# 2         103        1.0             NaN    NaN         NaN         NaN
# 3         201        1.0             NaN    NaN         NaN         NaN
# 4         203        1.0             NaN    NaN         NaN         NaN
# 5         311        1.0             NaN    NaN         NaN         NaN
# 6         312        1.0             NaN    NaN         NaN         NaN
# 7        5173        1.0             NaN    NaN         NaN         NaN
# 8        4223        NaN             1.0    NaN         NaN         NaN
# 9        4222        NaN             1.0    NaN         NaN         NaN
# 10       2523        NaN             1.0    NaN         NaN         NaN
# 11       5241        NaN             1.0    NaN         NaN         NaN
# 12       5242        NaN             1.0    NaN         NaN         NaN
# 13       5243        NaN             1.0    NaN         NaN         NaN
# 14       4221        NaN             1.0    NaN         NaN         NaN
# 15       4241        NaN             1.0    NaN         NaN         NaN
# 16       2253        NaN             NaN    1.0         NaN         NaN
# 17       2235        NaN             NaN    1.0         NaN         NaN
# 18       3222        NaN             NaN    1.0         NaN         NaN
# 19       5193        NaN             NaN    1.0         NaN         NaN
# 20       2237        NaN             NaN    1.0         NaN         NaN
# 21       2261        NaN             NaN    1.0         NaN         NaN
# 22       2253        NaN             NaN    1.0         NaN         NaN
# 23       2233        NaN             NaN    1.0         NaN         NaN
# 24       2124        NaN             NaN    NaN         1.0         NaN
# 25       1425        NaN             NaN    NaN         1.0         NaN
# 26       2341        NaN             NaN    NaN         1.0         NaN
# 27       2612        NaN             NaN    NaN         1.0         NaN
# 28       2122        NaN             NaN    NaN         1.0         NaN
# 29       3185        NaN             NaN    NaN         NaN         1.0
# 30       7152        NaN             NaN    NaN         NaN         1.0
# 31       8211        NaN             NaN    NaN         NaN         1.0
# 32       7701        NaN             NaN    NaN         NaN         1.0
# 33       7613        NaN             NaN    NaN         NaN         1.0
# 34       7111        NaN             NaN    NaN         NaN         1.0
# 35       5132        NaN             NaN    NaN         NaN         NaN
# 36       2711        NaN             NaN    NaN         NaN         NaN
# 37       5135        NaN             NaN    NaN         NaN         NaN
# 38       3252        NaN             NaN    NaN         NaN         NaN
# 39       8418        NaN             NaN    NaN         NaN         NaN
# 40       8414        NaN             NaN    NaN         NaN         NaN
# 41       7842        NaN             NaN    NaN         NaN         NaN
#
#     gastronomia
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          1.0
# 36          1.0
# 37          1.0
# 38          1.0
# 39          1.0
# 40          1.0
# 41          1.0

# %%
train = train.merge(test, on='codigoCbo')

# %%
train
# Out:
#     codigoCbo  seguranca  relacionamento  saude  tecnologia  manufatura  \
# 0         101        1.0             NaN    NaN         NaN         NaN
# 1         102        1.0             NaN    NaN         NaN         NaN
# 2         103        1.0             NaN    NaN         NaN         NaN
# 3         201        1.0             NaN    NaN         NaN         NaN
# 4         203        1.0             NaN    NaN         NaN         NaN
# 5         311        1.0             NaN    NaN         NaN         NaN
# 6         312        1.0             NaN    NaN         NaN         NaN
# 7        5173        1.0             NaN    NaN         NaN         NaN
# 8        4223        NaN             1.0    NaN         NaN         NaN
# 9        4222        NaN             1.0    NaN         NaN         NaN
# 10       2523        NaN             1.0    NaN         NaN         NaN
# 11       5241        NaN             1.0    NaN         NaN         NaN
# 12       5242        NaN             1.0    NaN         NaN         NaN
# 13       5243        NaN             1.0    NaN         NaN         NaN
# 14       4221        NaN             1.0    NaN         NaN         NaN
# 15       4241        NaN             1.0    NaN         NaN         NaN
# 16       2253        NaN             NaN    1.0         NaN         NaN
# 17       2253        NaN             NaN    1.0         NaN         NaN
# 18       2235        NaN             NaN    1.0         NaN         NaN
# 19       3222        NaN             NaN    1.0         NaN         NaN
# 20       5193        NaN             NaN    1.0         NaN         NaN
# 21       2237        NaN             NaN    1.0         NaN         NaN
# 22       2261        NaN             NaN    1.0         NaN         NaN
# 23       2233        NaN             NaN    1.0         NaN         NaN
# 24       2124        NaN             NaN    NaN         1.0         NaN
# 25       1425        NaN             NaN    NaN         1.0         NaN
# 26       2341        NaN             NaN    NaN         1.0         NaN
# 27       2612        NaN             NaN    NaN         1.0         NaN
# 28       2122        NaN             NaN    NaN         1.0         NaN
# 29       3185        NaN             NaN    NaN         NaN         1.0
# 30       7152        NaN             NaN    NaN         NaN         1.0
# 31       8211        NaN             NaN    NaN         NaN         1.0
# 32       7701        NaN             NaN    NaN         NaN         1.0
# 33       7613        NaN             NaN    NaN         NaN         1.0
# 34       7111        NaN             NaN    NaN         NaN         1.0
# 35       5132        NaN             NaN    NaN         NaN         NaN
# 36       2711        NaN             NaN    NaN         NaN         NaN
# 37       5135        NaN             NaN    NaN         NaN         NaN
# 38       3252        NaN             NaN    NaN         NaN         NaN
# 39       8418        NaN             NaN    NaN         NaN         NaN
# 40       8414        NaN             NaN    NaN         NaN         NaN
# 41       7842        NaN             NaN    NaN         NaN         NaN
#
#     gastronomia                                          unificado
# 0           NaN  Oficiais generais das forças armadas As funçõe...
# 1           NaN  Oficiais das forças armadas Estão compreendida...
# 2           NaN  Praças das forças armadas Estão compreendidas ...
# 3           NaN  Oficiais superiores da polícia militar Comanda...
# 4           NaN  Tenentes da polícia militar Comandam pelotão, ...
# 5           NaN  Subtenentes e sargentos do corpo de bombeiros ...
# 6           NaN  Cabos e soldados do corpo de bombeiros militar...
# 7           NaN  Vigilantes e guardas de segurança Vigiam depen...
# 8           NaN  Operadores de telemarketing Atendem usuários, ...
# 9           NaN  Operadores de telefonia Operam equipamentos, a...
# 10          NaN  Secretárias(os) executivas(os) e afins Assesso...
# 11          NaN  Vendedores em domicílio Vendem produtos e serv...
# 12          NaN  Vendedores em bancas, quiosques e barracas Ven...
# 13          NaN  Vendedores ambulantes Vendem mercadorias e ali...
# 14          NaN  Recepcionistas Recepcionam e prestam serviços ...
# 15          NaN  Entrevistadores e recenseadores Aplicam questi...
# 16          NaN  Médicos em medicina diagnóstica e terapêutica ...
# 17          NaN  Médicos em medicina diagnóstica e terapêutica ...
# 18          NaN  Enfermeiros e afins Prestam assistência ao pac...
# 19          NaN  Técnicos e auxiliares de enfermagem Desempenha...
# 20          NaN  Trabalhadores de serviços veterinários, de hig...
# 21          NaN  Nutricionistas Prestam assistência nutricional...
# 22          NaN  Osteopatas e quiropraxistas Tratam e atendem p...
# 23          NaN  Veterinários e zootecnistas Praticam clínica m...
# 24          NaN  Analistas de tecnologia da informação Desenvol...
# 25          NaN  Gerentes de tecnologia da informação Gerenciam...
# 26          NaN  Professores de matemática, estatística e infor...
# 27          NaN  Profissionais da informação Disponibilizam inf...
# 28          NaN  Engenheiros em computação Projetam soluções em...
# 29          NaN  Desenhistas projetistas de construção civil e ...
# 30          NaN  Trabalhadores de estruturas de alvenaria Organ...
# 31          NaN  Operadores de instalações de sinterização Oper...
# 32          NaN  Supervisores em indústria de madeira, mobiliár...
# 33          NaN  Operadores de tear e máquinas similares Prepar...
# 34          NaN  Trabalhadores da extração de minerais sólidos ...
# 35          1.0  Cozinheiros Organizam e supervisionam serviços...
# 36          1.0  Chefes de cozinha e afins Criam e elaboram pra...
# 37          1.0  Trabalhadores auxiliares nos serviços de alime...
# 38          1.0  Técnicos em produção, conservação  e de qualid...
# 39          1.0  Operadores de equipamentos na fabricação de pã...
# 40          1.0  Trabalhadores na fabricação e conservação de a...
# 41          1.0  Alimentadores de linhas de produção Preparam m...

# %%
test = test[~test['codigoCbo'].isin(train['codigoCbo'])]

# %%
COMMENT = 'unificado'
train[COMMENT].fillna("unknown", inplace=True)
test[COMMENT].fillna("unknown", inplace=True)

test.head()
# Out:
#    codigoCbo                                          unificado
# 4        202  Capitães da  polícia militar Comandam operaçõe...
# 6        211  Subtenentes e sargentos da policia militar Com...
# 7        212  Cabos e soldados da polícia militar Realizam p...
# 8        301  Oficiais superiores do corpo de bombeiros mili...
# 9        302  Oficiais intermediários do corpo de bombeiros ...

# %%
def  clean_and_tokenizing(text):
    # Remove numbers + punctuation        
    letters_only = re.sub("[^a-zA-Z]", " ", normalize('NFKD', text).encode('ASCII', 'ignore').decode('ASCII')) 

    # Convert to lower case, split into individual words
    words = letters_only.lower().split()                             

    # Save english stopwords
    stops = set(stopwords.words("portuguese"))                  

    # Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    
    # Join everython again
    #print(meaningful_words)
    #print(" ".join( meaningful_words ))
    return( " ".join( meaningful_words ))

# %%
n = train.shape[0]
vec = TfidfVectorizer(ngram_range=(1,2), tokenizer=clean_and_tokenizing,
               min_df=3, max_df=0.9, strip_accents='unicode', use_idf=1,
               smooth_idf=1, sublinear_tf=1 )
trn_term_doc = vec.fit_transform(train[COMMENT])
test_term_doc = vec.transform(test[COMMENT])

# %%
trn_term_doc
test_term_doc
# Out:
# <578x146 sparse matrix of type '<class 'numpy.float64'>'
# 	with 36085 stored elements in Compressed Sparse Row format>

# %%
def pr(y_i, y):
    p = x[y==y_i].sum(0)
    return (p+1) / ((y==y_i).sum()+1)

# %%
def get_mdl(y):
    y = y.values
    r = np.log(pr(1,y) / pr(0,y))
    m = LogisticRegression(C=4, dual=True)
    x_nb = x.multiply(r)
    return m.fit(x_nb, y), r

# %%
x = trn_term_doc

test_x = test_term_doc

# %%
train.fillna(0, inplace= True)

# %%
label_cols = list(train)[1:]

# %%
preds = np.zeros((len(test), len(label_cols)))

for i, j in enumerate(label_cols):
    print('fit', j)
    m,r = get_mdl(train[j])
    preds[:,i] = m.predict_proba(test_x.multiply(r))[:,1]
# Out:
# fit seguranca
# fit relacionamento
# fit saude
# fit tecnologia
# fit manufatura
# fit gastronomia
# fit unificado

# %%
submid = pd.DataFrame({'id': test["codigoCbo"]})
submission = pd.concat([submid, pd.DataFrame(preds, columns = label_cols)], axis=1)
submission.to_csv('submission.csv', index=False)
